# %% [markdown]
# **Figure Architecture**

# %%
root = "../data/plots/final"

import fitz  # PyMuPDF

def merge_vertically(pdf1_path, pdf2_path, output_path, padding=35, top_padding=20):
    TARGET_WIDTH_PT = 510  # 180 mm in points

    doc1 = fitz.open(pdf1_path)
    doc2 = fitz.open(pdf2_path)

    page1 = doc1[0]
    page2 = doc2[0]

    fig1_rect = page1.rect
    fig2_rect = page2.rect

    scale1 = TARGET_WIDTH_PT / fig1_rect.width
    scale2 = TARGET_WIDTH_PT / fig2_rect.width

    fig1_scaled_height = fig1_rect.height * scale1
    fig2_scaled_height = fig2_rect.height * scale2

    output_width = TARGET_WIDTH_PT
    output_height = top_padding + fig1_scaled_height + padding + fig2_scaled_height

    merged = fitz.open()
    new_page = merged.new_page(width=output_width, height=output_height)

    rect1 = fitz.Rect(0, top_padding, TARGET_WIDTH_PT, top_padding + fig1_scaled_height)
    rect2 = fitz.Rect(0, top_padding + fig1_scaled_height + padding,
                      TARGET_WIDTH_PT, output_height)

    new_page.show_pdf_page(rect1, doc1, 0, clip=fig1_rect)
    new_page.show_pdf_page(rect2, doc2, 0, clip=fig2_rect)

    # Labels with mixed font styles
    font_size = 10
    label_padding = 0
    label_offset = 18  # Fixed horizontal offset after label

    # A label
    label_a_x = rect1.x0 + label_padding
    label_a_y = rect1.y0 + label_padding - 10
    new_page.insert_text((label_a_x, label_a_y),
                         "A:", fontsize=font_size,
                         fontname="helvetica-bold", fill=(0, 0, 0))
    new_page.insert_text((label_a_x + label_offset, label_a_y),
                         "Deep architecture", fontsize=font_size,
                         fontname="helvetica", fill=(0, 0, 0))

    # B label
    label_b_x = rect2.x0 + label_padding
    label_b_y = rect2.y0 + label_padding - 10
    new_page.insert_text((label_b_x, label_b_y),
                         "B:", fontsize=font_size,
                         fontname="helvetica-bold", fill=(0, 0, 0))
    new_page.insert_text((label_b_x + label_offset, label_b_y),
                         "Localized architecture", fontsize=font_size,
                         fontname="helvetica", fill=(0, 0, 0))

    merged.save(output_path)
    merged.close()
    doc1.close()
    doc2.close()

# Usage
path1 = f'{root}/DeepSkip.pdf'
path2 = f'{root}/Local.pdf'
path3 = f'{root}/Architecture.pdf'

merge_vertically(path1, path2, path3)

# %% [markdown]
# **Figure Long-term**

# %%
import fitz  # PyMuPDF

def merge_vertically(pdf1_path, pdf2_path, pdf3_path, output_path, padding=35, top_padding=20):
    TARGET_WIDTH_PT = 510  # 180 mm in points
    width2_ratio = 0.745
    width3_ratio = 0.255

    doc1 = fitz.open(pdf1_path)
    doc2 = fitz.open(pdf2_path)
    doc3 = fitz.open(pdf3_path)

    page1 = doc1[0]
    page2 = doc2[0]
    page3 = doc3[0]

    fig1_rect = page1.rect
    fig2_rect = page2.rect
    fig3_rect = page3.rect

    # Scale Figure 1 to full width
    scale1 = TARGET_WIDTH_PT / fig1_rect.width
    h1 = fig1_rect.height * scale1

    # Set target widths
    width2 = width2_ratio * TARGET_WIDTH_PT
    width3 = width3_ratio * TARGET_WIDTH_PT

    # Scale both Figures 2 and 3 to same height (row_height)
    scale2 = width2 / fig2_rect.width
    scale3 = width3 / fig3_rect.width

    h2 = fig2_rect.height * scale2
    h3 = fig3_rect.height * scale2

    # Set common height for both figures (min of the two to avoid overflow)
    row_height = min(h2, h3)

    # Recompute scales to match row_height
    scale2 = row_height / fig2_rect.height
    scale3 = row_height / fig3_rect.height
    width2 = fig2_rect.width * scale2
    width3 = fig3_rect.width * scale3

    # Compute total height of the merged page
    output_height = top_padding + h1 + padding + row_height + padding

    merged = fitz.open()
    new_page = merged.new_page(width=TARGET_WIDTH_PT, height=output_height)

    # Placement rects
    rect1 = fitz.Rect(0, top_padding, TARGET_WIDTH_PT, top_padding + h1)

    y_row = rect1.y1 + padding
    rect2 = fitz.Rect(0, y_row, width2, y_row + row_height)
    rect3 = fitz.Rect(width2, y_row, width2 + width3, y_row + row_height)

    # Insert figures
    new_page.show_pdf_page(rect1, doc1, 0, clip=fig1_rect)
    new_page.show_pdf_page(rect2, doc2, 0, clip=fig2_rect)
    new_page.show_pdf_page(rect3, doc3, 0, clip=fig3_rect)

    # Labels
    font_size = 10
    label_offset_y = 12
    label_padding = 0

    # A: top
    new_page.insert_text((rect1.x0 + label_padding + 11, rect1.y0 - label_offset_y), "A:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect1.x0 + label_padding + 22, rect1.y0 - label_offset_y), " Lorenz-63", fontsize=font_size, fontname="helvetica")

    # B: bottom left
    new_page.insert_text((rect2.x0 + label_padding + 8, rect2.y0 - label_offset_y), "B:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect2.x0 + label_padding + 19, rect2.y0 - label_offset_y), " Lorenz-96", fontsize=font_size, fontname="helvetica")

    # C: bottom right
    new_page.insert_text((rect3.x0 + label_padding + 6, rect2.y0 - label_offset_y), "C:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect3.x0 + label_padding + 17, rect2.y0 - label_offset_y), " Kuramoto-Sivashinsky", fontsize=font_size, fontname="helvetica")

    # Save and close
    merged.save(output_path)
    merged.close()
    doc1.close()
    doc2.close()
    doc3.close()

# Usage
path1 = f'{root}/L63-climate.pdf'
path2 = f'{root}/L96-climate.pdf'
path3 = f'{root}/KS-200-climate.pdf'
path4 = f'{root}/Long-term.pdf'

merge_vertically(path1, path2, path3, path4)

# %% [markdown]
# **Figure: short-term**

# %%
import fitz  # PyMuPDF

def merge_vertically(pdf1_path, pdf2_path, pdf3_path, output_path, padding=35, top_padding=20):
    TARGET_WIDTH_PT = 510  # 180 mm in points

    doc1 = fitz.open(pdf1_path)
    doc2 = fitz.open(pdf2_path)
    doc3 = fitz.open(pdf3_path)

    page1 = doc1[0]
    page2 = doc2[0]
    page3 = doc3[0]

    fig1_rect = page1.rect
    fig2_rect = page2.rect
    fig3_rect = page3.rect

    # Compute the maximum original width
    max_original_width = max(fig1_rect.width, fig2_rect.width, fig3_rect.width)

    # Compute a uniform scale factor so the widest figure fits the target width
    scale = TARGET_WIDTH_PT / max_original_width

    # Compute scaled heights
    h1 = fig1_rect.height * scale
    h2 = fig2_rect.height * scale
    h3 = fig3_rect.height * scale

    # Compute scaled widths (for centered placement)
    w1 = fig1_rect.width * scale
    w2 = fig2_rect.width * scale
    w3 = fig3_rect.width * scale

    # Compute output page height
    output_height = top_padding + h1 + h2 + h3 + 2 * padding

    merged = fitz.open()
    new_page = merged.new_page(width=TARGET_WIDTH_PT, height=output_height)

    # Placement rectangles (centered horizontally)
    rect1 = fitz.Rect((TARGET_WIDTH_PT - w1) / 2, top_padding,
                      (TARGET_WIDTH_PT + w1) / 2, top_padding + h1)
    rect2 = fitz.Rect((TARGET_WIDTH_PT - w2) / 2, rect1.y1 + padding,
                      (TARGET_WIDTH_PT + w2) / 2, rect1.y1 + padding + h2)
    rect3 = fitz.Rect((TARGET_WIDTH_PT - w3) / 2, rect2.y1 + padding,
                      (TARGET_WIDTH_PT + w3) / 2, rect2.y1 + padding + h3)

    # Insert pages
    new_page.show_pdf_page(rect1, doc1, 0, clip=fig1_rect)
    new_page.show_pdf_page(rect2, doc2, 0, clip=fig2_rect)
    new_page.show_pdf_page(rect3, doc3, 0, clip=fig3_rect)

    # Labels
    font_size = 10
    label_offset_x = 5
    label_offset_y = 12

    # A: top
    new_page.insert_text((rect1.x0 + label_offset_x + 11, rect1.y0 - label_offset_y), "A:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect1.x0 + label_offset_x + 22, rect1.y0 - label_offset_y), " Lorenz-63", fontsize=font_size, fontname="helvetica")

    # B: bottom left
    new_page.insert_text((rect2.x0 + label_offset_x + 11, rect2.y0 - label_offset_y), "B:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect2.x0 + label_offset_x + 22, rect2.y0 - label_offset_y), " Lorenz-96", fontsize=font_size, fontname="helvetica")

    # C: bottom right
    new_page.insert_text((rect3.x0 + label_offset_x + 6, rect3.y0 - label_offset_y), "C:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect3.x0 + label_offset_x + 17, rect3.y0 - label_offset_y), " Kuramoto-Sivashinsky", fontsize=font_size, fontname="helvetica")

    merged.save(output_path)
    merged.close()
    doc1.close()
    doc2.close()
    doc3.close()

# Usage
path1 = f'{root}/L63-config_1_s-vpt-violin.pdf'
path2 = f'{root}/L96-config_1_s-vpt-violin.pdf'
path3 = f'{root}/KS-200-config_1-vpt-violin.pdf'
path4 = f'{root}/Short-term.pdf'

merge_vertically(path1, path2, path3, path4)

# %% [markdown]
# **Figure: Depth vs E[VPT]**

# %%
import fitz  # PyMuPDF
from io import BytesIO

root = "../data/plots/final"

def merge_horizontally(pdf1_path, pdf2_path, output_path, padding=35, side_padding=20):
    TARGET_WIDTH_PT = 250  # Adjust width as needed

    doc1 = fitz.open(pdf1_path)
    doc2 = fitz.open(pdf2_path)

    page1 = doc1[0]
    page2 = doc2[0]

    # Get original sizes
    fig1_rect = page1.rect
    fig2_rect = page2.rect

    # Calculate scale factors to make both widths TARGET_WIDTH_PT
    scale1 = TARGET_WIDTH_PT / fig1_rect.width
    scale2 = TARGET_WIDTH_PT / fig2_rect.width

    # Calculate new heights based on scale
    fig1_scaled_height = fig1_rect.height * scale1
    fig2_scaled_height = fig2_rect.height * scale2

    output_width = side_padding + TARGET_WIDTH_PT + padding + TARGET_WIDTH_PT + side_padding
    output_height = max(fig1_scaled_height, fig2_scaled_height) + 40  # 40pt extra for labels

    merged = fitz.open()
    new_page = merged.new_page(width=output_width, height=output_height)

    # Define placement rectangles (stacked horizontally)
    rect1 = fitz.Rect(side_padding, 40, side_padding + TARGET_WIDTH_PT, 40 + fig1_scaled_height)
    rect2 = fitz.Rect(side_padding + TARGET_WIDTH_PT + padding, 40,
                      side_padding + TARGET_WIDTH_PT + padding + TARGET_WIDTH_PT, 40 + fig2_scaled_height)

    # Show scaled figures
    new_page.show_pdf_page(rect1, doc1, 0, clip=fig1_rect)
    new_page.show_pdf_page(rect2, doc2, 0, clip=fig2_rect)

    # Labels
    font_size = 11
    label_offset_x = 15
    label_offset_y = 12

    new_page.insert_text((rect1.x0 + label_offset_x + 17, rect1.y0 - label_offset_y), "A:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect1.x0 + label_offset_x + 28, rect1.y0 - label_offset_y), " Lorenz-63", fontsize=font_size, fontname="helvetica")

    new_page.insert_text((rect2.x0 + label_offset_x + 12, rect2.y0 - label_offset_y), "B:", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect2.x0 + label_offset_x + 23, rect2.y0 - label_offset_y), " Lorenz-96", fontsize=font_size, fontname="helvetica")

    # Save
    merged.save(output_path)
    merged.close()
    doc1.close()
    doc2.close()

# Usage
path1 = f'{root}/L63-depth.pdf'
path2 = f'{root}/L96-depth.pdf'
path3 = f'{root}/Depth.pdf'

merge_horizontally(path1, path2, path3)

# %% [markdown]
# **Figure: Sampling-time**

# %%
import fitz  # PyMuPDF
from io import BytesIO

root = "../data/plots/final"

def merge_horizontally(pdf1_path, pdf2_path, output_path, padding=35, side_padding=20):
    TARGET_WIDTH_PT = 250  # Adjust width as needed

    doc1 = fitz.open(pdf1_path)
    doc2 = fitz.open(pdf2_path)

    page1 = doc1[0]
    page2 = doc2[0]

    # Get original sizes
    fig1_rect = page1.rect
    fig2_rect = page2.rect

    # Calculate scale factors to make both widths TARGET_WIDTH_PT
    scale1 = TARGET_WIDTH_PT / fig1_rect.width
    scale2 = TARGET_WIDTH_PT / fig2_rect.width

    # Calculate new heights based on scale
    fig1_scaled_height = fig1_rect.height * scale1
    fig2_scaled_height = fig2_rect.height * scale2

    output_width = side_padding + TARGET_WIDTH_PT + padding + TARGET_WIDTH_PT + side_padding
    output_height = max(fig1_scaled_height, fig2_scaled_height) + 40  # 40pt extra for labels

    merged = fitz.open()
    new_page = merged.new_page(width=output_width, height=output_height)

    # Define placement rectangles (stacked horizontally)
    rect1 = fitz.Rect(side_padding, 40, side_padding + TARGET_WIDTH_PT, 40 + fig1_scaled_height)
    rect2 = fitz.Rect(side_padding + TARGET_WIDTH_PT + padding, 40,
                      side_padding + TARGET_WIDTH_PT + padding + TARGET_WIDTH_PT, 40 + fig2_scaled_height)

    # Show scaled figures
    new_page.show_pdf_page(rect1, doc1, 0, clip=fig1_rect)
    new_page.show_pdf_page(rect2, doc2, 0, clip=fig2_rect)

    # Labels
    font_size = 11
    label_offset_x = 15
    label_offset_y = 12

    new_page.insert_text((rect1.x0 + label_offset_x + 17, rect1.y0 - label_offset_y), "A", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect1.x0 + label_offset_x + 28, rect1.y0 - label_offset_y), " ", fontsize=font_size, fontname="helvetica")

    new_page.insert_text((rect2.x0 + label_offset_x + 10, rect2.y0 - label_offset_y), "B", fontsize=font_size, fontname="helvetica-bold")
    new_page.insert_text((rect2.x0 + label_offset_x + 21, rect2.y0 - label_offset_y), " ", fontsize=font_size, fontname="helvetica")

    # Save
    merged.save(output_path)
    merged.close()
    doc1.close()
    doc2.close()

# Usage
path1 = f'{root}/L63-dt-01-vpt.pdf'
path2 = f'{root}/comparison-LS-more.pdf'
path3 = f'{root}/Sampling-time.pdf'

merge_horizontally(path1, path2, path3)
