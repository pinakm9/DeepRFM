# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
import seaborn as sns
import oneshot as sm
import rfm, skipRFM, deepSkip, localSkip_2_2, localDeepSkip_8_1, localDeepSkip_2_2, localSkip_8_1, localSkip
# import parallel_euler as arch1
import torch
from torch import nn
import ks, l63, l96, ks_torch, ks0, ks1
import config

# %% [markdown]
# **Do V and KT match on small KS? (Yes they do)**

# %%
L, dt, N = 3, 0.25, 150
tau = {'error_threshold' : 0.25, 'dt': dt, 'Lyapunov_time': 1}
dns  = ks.KS(L=L, dt=dt, N=N, tend=1000)
dns.simulate()
uu = ks0.ks(L=L, dt=dt, N=N, tmax=1000)
ut.waterfall(uu-dns.uu, **tau)

# %% [markdown]
# **Look at the covariance structure**

# %%
im = plt.matshow(np.cov(uu))
plt.colorbar(im)

# %% [markdown]
# **Try SkipRFM**

# %%
train, test = ks.gen_data(L=L, N=N, train_size=int(1e5), test_num=100)
train, test = torch.tensor(train), torch.tensor(test)
L0, L1 = 0.4, 3.5
D, D_r, B = N, 128, 1
beta = 5e-8
data_folder = '../data'
drf_args = [D_r, B, L0, L1, train, beta, 'SkipRFM', f'{data_folder}/SkipKS-small', False]
batch = skipRFM.BatchDeepRF(train, test, *drf_args)
batch.drf.learn(train, 42)
print(batch.get_tau_f(batch.drf, test[47], error_threshold=0.25, dt=1, Lyapunov_time=1))
# Out:
# Time taken by gen_data is 8.9031 seconds
# tensor([19.0000, 19.0000,  0.2421,  0.0897])

# %% [markdown]
# **Try LocalSkip**

# %%
drf_args = [512, 1, L0, L1, train, beta, 'LocalSkip', f'{data_folder}/LocalSkipKS-small', False, 5, 1]
drf = localSkip.DeepRF(*drf_args)
drf.learn(train, 42)
print(drf.compute_tau_f(test[:10], error_threshold=0.25, dt=1, Lyapunov_time=1)[0])
# Out:
# Time taken by compute_tau_f is 0.3457 seconds
# tensor([2., 2., 2., 2., 2., 2., 2., 2., 2., 2.])
