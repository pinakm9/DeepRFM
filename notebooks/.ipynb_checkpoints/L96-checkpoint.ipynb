# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
from scipy.signal import welch
import seaborn as sns
import oneshot as sm
import rfm, skipRFM, deepSkip, localSkip, localDeepSkip
# import parallel_euler as arch1
import torch
from torch import nn
import l96, glob, shutil
import config as cf

dynamical_system = 'L96'
folder = f'../data/{dynamical_system}'
config = 'config_1_s' 
# ut.gather_beta('L96')

# %% [markdown]
# **Find optimal localization**

# %%
config = 'config_local'
architectures = ['LocalSkip']#, 'LocalDeepSkip']
GI = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 2], [2, 3], [4, 1], [4, 2], [4, 3]]
localizations = [GI, GI]
D_rB = [[4096, 1]] * 9
structures = [D_rB, D_rB]
markers = ['x', 'v']
fig = plt.figure(figsize=(8, 5.2))
ax = fig.add_subplot(111)
smoothing_window = 5
for i, architecture in enumerate(architectures):
    for j, localization in enumerate(localizations[i]):
        G, I = localization
        D_r, B = structures[i][j]
        if G==1:
            linestyle = 'dashed'
        elif G==2:
            linestyle = 'solid'
        elif G==4:
            linestyle = 'dotted'
        data = pd.read_csv(f'{folder}/{config}/{architecture}_{G}_{I}/beta/beta_D_r-{D_r}_B-{B}.csv')
        x, y = data['beta'], data['tau_f_nmse_mean']
        y = ut.smooth(y, smoothing_window)
        ax.semilogx(x, y, label=f'{architecture}_{G}_{I}', linestyle=linestyle)#, s=20, marker=markers[i])
ax.legend()
ax.set_xlabel(r'$\beta$')
ax.set_ylabel(r'$\mathbb{E}[{\rm VPT}]$')
ax.set_xlim((1e-14, 2e-5))
fig.suptitle('L96-localization schemes')
plt.savefig(f'../data/plots/L96-localization-schemes.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# **Violin plot of VPT**

# %%
config = 'config_1_s'
architectures = {'config_1_s':['SkipRFM', 'DeepSkip', 'LocalSkip_2_2', 'LocalDeepSkip_2_2']}
colors = {'config_0':['b', 'g'], 'config_1_s':['r', 'b', 'g', 'deeppink'], 'config_0_s':['b', 'g']}
x_pos = {'config_0':[2, 10], 'config_1_s':[1.5, 5.5, 10, 15], 'config_0_s':[2, 10]}
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(111)
smoothing_window = 5
m, n = 0, 0
params = []
best = []
for i, architecture in enumerate(architectures[config]):
    df_data = {'#params': [], 'vpt': []}
    subfolders = [x for x in glob.glob(f'{folder}/{config}/{architecture}/*') if not 'beta' in x]
    subfolders = [x for x in subfolders if os.path.exists(f'{x}/batch_data.csv')]
    sf = [x for x in subfolders if 'LocalDeepSkip' in x]
    subfolders = [x for x in subfolders if 'LocalDeepSkip' not in x]
    sf = [x for x in sf if (ut.get_arch(x)[2:4] in [[1024, 32], [2048, 16], [4096, 8], [8192, 4], [16384, 2]])]
    subfolders += sf
    subfolders = [x for x in subfolders if "512" not in x]
    subfolders = [x for x in subfolders if ("DeepSkip/D_r-4096_B-1" not in x) or ("DeepSkip/D_r-4096_B-16" in x)]
    sizes = [[x[2], x[3]] for x in list(map(ut.get_arch, subfolders))]
    means = [pd.read_csv(f'{x}/batch_data.csv')['tau_f_nmse'].mean() for x in subfolders]
    subfolders = [x for _, x in sorted(zip(sizes, subfolders))]
    n += len(subfolders)-1 
    # print(subfolders)
    for j, subfolder in enumerate(subfolders):
        arch = ut.get_arch(subfolder)
        data = pd.read_csv(f'{subfolder}/batch_data.csv')
        vpt = data['tau_f_nmse']
        p = np.log10(arch[-1])
        df_data['#params'] += [m] * len(vpt)
        df_data['vpt'] += vpt.to_list()
        params += [p]
        if architecture == "LocalSkip_2_2" or architecture == "SkipRFM":
            text = r"{}".format(int(np.log2(arch[2]))) 
        else:
            text = r"{}, {}".format(int(np.log2(arch[2])), arch[3])
        # if j == np.argmax(means):
        #     text += r'$^*$'
        ax.text(m-0.2, vpt.max()+1.1, text)
        m += 1
    df = pd.DataFrame(df_data)
    sns.violinplot(data=df, x="#params", y="vpt", ax=ax, color=colors[config][i])
    best += [max(means)]
ax.set_xticks(x_pos[config], labels=[architectures[config][i].split('_')[0] + r', best $\mathbb{E}[\rm VPT]=$' + f'{best[i]:.2f}' for i in range(len(architectures[config]))])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel(r'')
ax.set_ylabel(r'${\rm VPT}$')
ax.set_ylim((0, 14))
# ax.set_ylim((0, 70))
# fig.suptitle('L96-localization schemes')
plt.savefig(f'../data/plots/{dynamical_system}-{config}-vpt-violin.pdf', bbox_inches='tight', dpi=1200)

# %% [markdown]
# **Folder fix**

# %%
# for folder in glob.glob('../data/L96/config_1_s/LocalDeepSkip/*'):
#     if not 'beta' in folder:
#         shutil.move(folder, folder.replace('_2_2', ''))

# %% [markdown]
# **Summary of experiments**

# %%
ut.summary('L96');
# Out:
# Looking at data for L96-config_0-LocalSkip_2_2:
# (256, 1, 2, 2): 2.9634396000000005
# (512, 1, 2, 2): 4.440982599999999
# (1024, 1, 2, 2): 5.536303000000001
# (2048, 1, 2, 2): 5.9969768000000006
# (4096, 1, 2, 2): 6.501098400000001
# (8192, 1, 2, 2): 7.0266034
# (16384, 1, 2, 2): 7.2566906
# Looking at data for L96-config_0-SkipRFM:
# (256, 1): 0.26332
# (512, 1): 0.3337808
# (16384, 1): 0.7013916
# (1024, 1): 0.9970294000000002
# (2048, 1): 2.0148974
# (4096, 1): 2.289522
# (8192, 1): 2.3845896000000004
# Looking at data for L96-config_1-LocalDeepSkip_2_2:
# (1024, 1, 2, 2): 5.112630200000001
# (1024, 2, 2, 2): 5.558367400000001
# (1024, 4, 2, 2): 5.687757400000001
# (1024, 8, 2, 2): 5.762667400000001
# (1024, 16, 2, 2): 5.896960600000001
# (4096, 2, 2, 2): 6.3180456000000005
# (4096, 4, 2, 2): 6.5858602
# (4096, 8, 2, 2): 6.636118000000001
# (8192, 2, 2, 2): 6.8757846
# (8192, 4, 2, 2): 7.107143
# (16384, 2, 2, 2): 7.142555000000001
# Looking at data for L96-config_1-LocalSkip_2_2:
# (512, 1, 2, 2): 4.3541324
# (1024, 1, 2, 2): 5.294820400000001
# (2048, 1, 2, 2): 5.727800200000001
# (4096, 1, 2, 2): 6.4571966000000005
# (8192, 1, 2, 2): 6.721106799999999
# (16384, 1, 2, 2): 6.8167192
# Looking at data for L96-config_1-SkipRFM:
# (512, 1): 0.3149398
# (1024, 1): 0.9756006000000002
# (2048, 1): 2.0528518
# (4096, 1): 2.2705448
# (8192, 1): 2.3242984
# Looking at data for L96-config_1-DeepSkip:
# (1024, 1): 0.8390373999999999
# (1024, 2): 0.951584
# (1024, 4): 1.0136912
# (1024, 8): 1.0756168000000002
# (1024, 16): 1.1327754
# Looking at data for L96-config_1_s-LocalDeepSkip_2_2:
# (1024, 1, 2, 2): 5.4977584
# (1024, 2, 2, 2): 5.7808274
# (2048, 1, 2, 2): 5.814605
# (1024, 4, 2, 2): 5.9552996
# (4096, 1, 2, 2): 6.0183148
# (1024, 8, 2, 2): 6.0447376
# (1024, 16, 2, 2): 6.0596288000000005
# (8192, 1, 2, 2): 6.2302420000000005
# (1024, 32, 2, 2): 6.2588894
# (2048, 2, 2, 2): 6.3139596000000004
# (2048, 4, 2, 2): 6.431681800000001
# (2048, 8, 2, 2): 6.511722
# (4096, 2, 2, 2): 6.557031200000001
# (2048, 16, 2, 2): 6.635391600000001
# (4096, 4, 2, 2): 6.7279622
# (2048, 32, 2, 2): 6.737632400000001
# (8192, 2, 2, 2): 6.769775600000001
# (4096, 8, 2, 2): 6.8809602000000005
# (8192, 4, 2, 2): 7.0121662
# (4096, 16, 2, 2): 7.013482799999999
# (16384, 1, 2, 2): 7.035955800000002
# (8192, 8, 2, 2): 7.056295
# (16384, 4, 2, 2): 7.235761200000001
# (16384, 2, 2, 2): 7.306585200000001
# Looking at data for L96-config_1_s-LocalSkip_2_2:
# (512, 1, 2, 2): 4.3541324
# (1024, 1, 2, 2): 5.294820400000001
# (2048, 1, 2, 2): 5.727800200000001
# (4096, 1, 2, 2): 6.4571966000000005
# (8192, 1, 2, 2): 6.721106799999999
# (16384, 1, 2, 2): 6.8167192
# Looking at data for L96-config_1_s-SkipRFM:
# (512, 1): 0.3327366
# (1024, 1): 0.9674740000000002
# (2048, 1): 2.0302426000000002
# (4096, 1): 2.2464828000000003
# (8192, 1): 2.321529
# Looking at data for L96-config_1_s-DeepSkip:
# (4096, 1): 2.3073188
# (4096, 2): 2.6813694000000003
# (4096, 4): 2.7442938
# (4096, 8): 2.80799
# (4096, 16): 2.8483959999999997
# Looking at data for L96-config_local-LocalDeepSkip_1_3:
# Looking at data for L96-config_local-LocalDeepSkip_1_2:
# Looking at data for L96-config_local-LocalSkip_4_3:
# Looking at data for L96-config_local-LocalSkip_2_1:
# Looking at data for L96-config_local-LocalSkip_4_2:
# Looking at data for L96-config_local-LocalDeepSkip_2_3:
# Looking at data for L96-config_local-LocalDeepSkip_4_1:
# Looking at data for L96-config_local-LocalDeepSkip_2_2:
# Looking at data for L96-config_local-LocalSkip_1_1:
# Looking at data for L96-config_local-LocalDeepSkip_1_1:
# Looking at data for L96-config_local-LocalSkip_2_2:
# Looking at data for L96-config_local-LocalSkip_2_3:
# Looking at data for L96-config_local-LocalSkip_4_1:
# Looking at data for L96-config_local-LocalDeepSkip_4_2:
# Looking at data for L96-config_local-LocalDeepSkip_4_3:
# Looking at data for L96-config_local-LocalDeepSkip_2_1:
# Looking at data for L96-config_local-LocalSkip_1_2:
# Looking at data for L96-config_local-LocalSkip_1_3:

# %% [markdown]
# **Generate reconstructed attractor**

# %%
L0, L1, N = 0.4, 3.5, int(1e5)
train = np.load(f"{folder}/train.npy")
train = torch.tensor(train)[:, :N]

# SkipRFM
# arch, D_r, B = 'SkipRFM', 8192, 1
# save_folder = f"{folder}/{config}/{arch}/D_r-{D_r}_B-{B}"
# beta_data = pd.read_csv(f"{folder}/{config}/{arch}/beta/beta_s.csv")
# beta = float(beta_data[(beta_data['D_r']==D_r) & (beta_data['B']==1)]['beta'].iloc[0])
# drf = skipRFM.DeepRF(D_r, B, L0, L1, train, beta, name=arch, save_folder=save_folder)
# drf.learn(train, 42)
# reconstructed_attractor = drf.multistep_forecast(train[:, 0], N)
# np.save(f"{save_folder}/attractor.npy", reconstructed_attractor)

# DeepSkip
# arch, D_r, B = 'DeepSkip', 8192, 2
# save_folder = f"{folder}/{config}/{arch}/D_r-{D_r}_B-{B}"
# beta_data = pd.read_csv(f"{folder}/{config}/{arch}/beta/beta_s.csv")
# beta = float(beta_data[(beta_data['D_r']==D_r) & (beta_data['B']==1)]['beta'].iloc[0])
# drf = deepSkip.DeepRF(D_r, B, L0, L1, train, beta, name=arch, save_folder=save_folder)
# drf.learn(train, 42)
# reconstructed_attractor = drf.multistep_forecast(train[:, 0], N)
# np.save(f"{save_folder}/attractor.npy", reconstructed_attractor)

# LocalSkipRFM 
# arch, D_r, B, G, I = 'LocalSkip_2_2', 16384, 1, 2, 2
# save_folder = f"{folder}/{config}/{arch}/D_r-{D_r}_B-{B}"
# beta_data = pd.read_csv(f"{folder}/{config}/{arch}/beta/beta_s.csv")
# beta = float(beta_data[(beta_data['D_r']==D_r) & (beta_data['B']==1)]['beta'].iloc[0])
# drf = localSkip.DeepRF(D_r, B, L0, L1, train, beta, name=arch, save_folder=save_folder, G=G, I=I)
# drf.learn(train, 42)
# reconstructed_attractor = drf.multistep_forecast(train[:, 0], N)
# np.save(f"{save_folder}/attractor.npy", reconstructed_attractor)

# LocalDeepSkip
# arch, D_r, B, G, I = 'LocalDeepSkip_2_2', 16384, 2, 2, 2
# save_folder = f"{folder}/{config}/{arch}/D_r-{D_r}_B-{B}"
# beta_data = pd.read_csv(f"{folder}/{config}/{arch}/beta/beta_s.csv")
# beta = float(beta_data[(beta_data['D_r']==D_r) & (beta_data['B']==1)]['beta'].iloc[0])
# drf = localDeepSkip.DeepRF(D_r, B, L0, L1, train, beta, name=arch, save_folder=save_folder, G=G, I=I)
# drf.learn(train, 42)
# reconstructed_attractor = drf.multistep_forecast(train[:, 0], N)
# np.save(f"{save_folder}/attractor.npy", reconstructed_attractor)

# %% [markdown]
# **Plot PSD data**

# %%
fig = plt.figure(figsize=(11, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
D_r, N = 4096, 100000
folders = [f"{folder}/{config}/SkipRFM/D_r-{D_r}_B-1", f"{folder}/{config}/DeepSkip/D_r-{D_r}_B-2",\
           f"{folder}/{config}/LocalSkip_2_2/D_r-{D_r}_B-1", f"{folder}/{config}/LocalDeepSkip_2_2/D_r-{D_r}_B-2", folder]
for i, data_folder in enumerate(folders):
    filename = "attractor" if i < len(folders)-1 else "train"
    attractor = np.load(f"{data_folder}/{filename}.npy")[:, :N]
    label = "Truth" if i == len(folders)-1 else ut.get_arch(data_folder)[0]
    # x, y = welch(attractor.mean(axis=0), 100)
    ax2.psd(attractor.mean(axis=0), Fs=100, label=label)
    sns.histplot(attractor[0], ax=ax1, label=label, alpha=0.7, stat="probability", bins=100)
ax1.legend()
ax1.set_xlabel(r'$x_1$')
ax1.set_ylabel('')
ax1.set_ylim((0, 0.041))
ax2.legend()
ax2.grid(False)
ax2.set_xlabel('Frequency (Hz)')
fig.subplots_adjust(wspace=0.3)
plt.savefig('../data/plots/L96-climate.pdf', dpi=1200, bbox_inches="tight")

# %%
data = pd.read_csv(f'{folder}/{config}/SkipRFM/D_r-{2*D_r}_B-{1}/batch_data.csv')
sns.violinplot(data['tau_f_nmse'])
# Out:
# <Axes: ylabel='tau_f_nmse'>
