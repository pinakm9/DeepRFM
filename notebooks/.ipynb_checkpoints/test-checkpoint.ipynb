# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
import seaborn as sns
import oneshot as sm
import rfm, skipRFM, deepSkip, localSkip_2_2, localDeepSkip_8_1, localDeepSkip_2_2, localSkip_8_1, localSkip81, localSkip_16_1
# import parallel_euler as arch1
import torch
from torch import nn
import ks, l63, l96, ks_torch, ks0
import config
# warnings.filterwarnings('ignore'

dynamical_system = 'KS'
# Uo = torch.tensor(np.load('../../deeprf/data/L63-trajectories/train1.npy'))
# Vo = torch.tensor(np.load('../../deeprf/data/L63-trajectories/test.npy'))
Uo = torch.tensor(np.load(f'../data/{dynamical_system}-200/train.npy'))[:, :100000]
Vo = torch.tensor(np.load(f'../data/{dynamical_system}-200/test.npy'))
# Uo = torch.tensor(ks0.ks32(dt=0.01, tmax=300)[:, 4000:-1000])

L0, L1 = 0.4, 3.5
D, D_r, B = 3, 128, 1
beta = 5e-3
m = 1024
data_folder = '../data'

# train, test = l96.gen_data(save_folder='../data/L96-trajectories')
drf_args = [500, 1, L0, L1, Uo, beta, 'LocalSkip_8_1', f'{data_folder}/localSkipKS/depth-{B}', False]
batch = localSkip_2_2.BatchDeepRF(Uo, Vo, *drf_args)
batch.drf.learn(Uo, 42)
kwargs = {'error_threshold' : 0.25, 'dt': 0.25, 'Lyapunov_time': 1/0.094}
# tau = drf.compute_tau_f(Vo[:100], **)
# tau = drf.compute_tau_f(Vo[:100], **{'error_threshold' : 0.09, 'dt': 0.01, 'Lyapunov_time': 1/2.27})
# tau[0].mean()
batch.get_tau_f(batch.drf, Uo[:, :], error_threshold=0.25, dt=1, Lyapunov_time=1)
eval = batch.drf.multistep_forecast(Uo[:, 0], 100)
std = Uo.std(axis=1)
diff = ((Uo[:, :100] - eval[:, :])**2 / std[:, None]**2).mean(axis=0)
plt.plot(np.arange(len(diff)), diff)
plt.axhline(0.25)
print(batch.get_tau_f(batch.drf, Uo[:, :], error_threshold=0.25, dt=1, Lyapunov_time=1))
# Out:
# tensor([8.0000, 8.0000, 0.2016, 0.1934])

# %%
for D_r, B in [[1024, 1], [1024, 2], [1024, 4], [1024, 8], [1024, 16], [4096, 1], [4096, 2], [4096, 4], [4096, 8]]:
    data = ut.get_data('L63', 1, 'DeepSkip', D_r, B)
    y = data['tau_f_nmse'].min()
    print(f'{D_r}, {B}, {y}')

for D_r, B in [[512, 1], [1024, 1], [2048, 1], [4096, 1], [8192, 1], [16384, 1]]:
    data = ut.get_data('L63', 1, 'SkipRFM', D_r, B)
    y = data['tau_f_nmse'].min()
    print(f'{D_r}, {B}, {y}')

for D_r, B in [[512, 1], [1024, 1], [2048, 1], [4096, 1], [8192, 1], [16384, 1]]:
    data = ut.get_data('L63', 1, 'RFM', D_r, B)
    y = data['tau_f_nmse'].min()
    print(f'{D_r}, {B}, {y}')
# Out:
# 1024, 1, 4.0404
# 1024, 2, 5.8695
# 1024, 4, 5.6238
# 1024, 8, 5.2598
# 1024, 16, 5.3053
# 4096, 1, 4.8503
# 4096, 2, 5.005
# 4096, 4, 6.3791
# 4096, 8, 5.1779
# 512, 1, 5.1142
# 1024, 1, 5.2689
# 2048, 1, 4.9231
# 4096, 1, 6.461
# 8192, 1, 5.214300000000001
# 16384, 1, 4.9595
# 512, 1, 3.9676
# 1024, 1, 4.995900000000001
# 2048, 1, 6.0151
# 4096, 1, 3.7674
# 8192, 1, 3.7765
# 16384, 1, 4.9231

# %%
ut.waterfall(Vo[0][:,:30], levels=50,  **kwargs)

# %%
ut.waterfall(eval[:, :25], levels=50,  **kwargs)

# %%
D, l, t = 512, 1, 5
plt.plot(range(D), Uo[:, t], label="Truth")
plt.plot(range(D), eval[:, t], label="Prediction")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 D, l, t = 512, 1, 5
#       2 plt.plot(range(D), Uo[:, t], label="Truth")
# ----> 3 plt.plot(range(D), eval[:, t], label="Prediction")
#       4 plt.legend()
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
29*0.094*0.25
# Out:
# 0.6815

# %%
a = np.random.normal(size=(3, 4))

# %%
a[0,...]
# Out:
# array([ 0.8594465 ,  0.76970808, -0.44920507,  0.44890045])

# %%
batch.drf.net.idx.shape
# Out:
# torch.Size([64, 24])

# %%
Uo.shape
# Out:
# torch.Size([512, 100000])

# %%
a = Uo.T[..., batch.drf.net.idx[0]]

# %%
torch.hstack([a, a]).shape
# Out:
# torch.Size([100000, 48])
